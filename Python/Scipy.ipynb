# %% [markdown]
# https://www.youtube.com/watch?v=jmX4FOUEfgU

# %%
from scipy.optimize import minimize

# %%
def f(x): return (x[0]+3)**3 +(x[1]+2)**2
restricao=[{'type': "ineq","fun": lambda x: -x[0]**2 - x[1]**2 +4}]

res=minimize(f,[3,2],constraints=restricao)
print(res)
# Out:
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 2.9988803841767044
#        x: [-1.788e+00 -8.960e-01]
#      nit: 20
#      jac: [ 4.406e+00  2.208e+00]
#     nfev: 63
#     njev: 20

# %% [markdown]
# ## Interpolação

# %%
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt
from numpy import linspace
x=[0,1,2,3,4,5]
y=[1,-3,10,35,50,60]
f= interp1d(x,y,kind='quadratic')
x_dense=linspace(0,5,100)
y_dense=f(x_dense)
plt.plot(x_dense,y_dense)
plt.scatter(x,y,color=red)

# %% [markdown]
# ##Curve Fitting

# %%
import numpy as np
def func(t,A,w,phi):
    return A*np.cos(w*t+phi)
from scipy.optimize import curve_fit
x_data = np.array([ 0.   ,  0.34482759,  0.68965517,  1.03448276,  1.37931034,
        1.72413793,  2.06896552,  2.4137931 ,  2.75862069,  3.10344828,
        3.44827586,  3.79310345,  4.13793103,  4.48275862,  4.82758621,
        5.17241379,  5.51724138,  5.86206897,  6.20689655,  6.55172414,
        6.89655172,  7.24137931,  7.5862069 ,  7.93103448,  8.27586207,
        8.62068966,  8.96551724,  9.31034483,  9.65517241, 10.        ])
y_data = np.array([ 4.3303953 ,  1.61137995, -2.15418696, -3.90137249, -1.67259042,
        2.16884383,  3.86635998,  1.85194506, -1.8489224 , -3.96560495,
       -2.13385255,  1.59425817,  4.06145238,  1.89300594, -1.76870297,
       -4.26791226, -2.46874133,  1.37019912,  4.24945607,  2.27038039,
       -1.50299303, -3.46774049, -2.50845488,  1.20022052,  3.81633703,
        2.91511556, -1.24569189, -3.72716214, -2.54549857,  0.87262548])
a,b=curve_fit(func,x_data,y_data,[4,np.pi,0]) #depende das condições inicias
plt.plot(x_data,y_data,label="data")
t=np.linspace(0,10,1000)
y=func(t,a[0],a[1],a[2])
plt.plot(t,y,label="fitting")
plt.legend()

# %% [markdown]
# ##Integral e Derivada

# %%
from scipy.misc import derivative
def f(x):
    return x**2 * np.sin(2*x) *np.exp(-x)
x = np.linspace(0, 1, 100)
plt.plot(x, f(x))
plt.plot(x, derivative(f, x, dx=1e-6))
plt.plot(x, derivative(f, x, dx=1e-6, n=2))
plt.grid()
# Out:
# <ipython-input-18-db6ce9718203>:6: DeprecationWarning: scipy.misc.derivative is deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. You may consider using findiff: https://github.com/maroba/findiff or numdifftools: https://github.com/pbrod/numdifftools
#   plt.plot(x, derivative(f, x, dx=1e-6))
# <ipython-input-18-db6ce9718203>:7: DeprecationWarning: scipy.misc.derivative is deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. You may consider using findiff: https://github.com/maroba/findiff or numdifftools: https://github.com/pbrod/numdifftools
#   plt.plot(x, derivative(f, x, dx=1e-6, n=2))

# %% [markdown]
# ## **Equações diferencias**
